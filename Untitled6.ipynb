# %%
# !conda install -c conda-forge wordcloud==1.4.1 --yes
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - wordcloud==1.4.1
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     wordcloud-1.4.1            |           py36_0         324 KB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         471 KB
#
# The following NEW packages will be INSTALLED:
#
#     wordcloud: 1.4.1-py36_0     conda-forge
#
# The following packages will be UPDATED:
#
# ...

# %%
from wordcloud import WordCloud,STOPWORDS

# %%
# !wget --quiet https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/alice_novel.txt

# %%
novel = open('alice_novel.txt', 'r').read()

# %%
stopwords = set(STOPWORDS)

# %%
novel_wc = WordCloud(
    background_color='yellow',
    max_words = 2000, 
    stopwords = stopwords
)

# %%
novel_wc.generate(novel)

# %%
import matplotlib.pyplot as plt
plt.imshow(novel_wc, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
modify = plt.figure()
modify.set_figwidth(20)
modify.set_figheight(30)

# %%
plt.imshow(novel_wc, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
# !wget --quiet https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Images/alice_mask.png

# %%
import numpy as np
novel_mask = np.array(open('alice_mask.png'))

# %%
fig=plt.figure()
fig.set_figwidth(20)
fig.set_figheight(30)

# %%
plt.imshow(novel_mask, cmap=plt.cm.gray, interpolation = 'bilinear' )
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-ee87db1af9a5> in <module>
# ----> 1 plt.imshow(novel_mask, cmap=plt.cm.gray, interpolation = 'bilinear' )
#       2 plt.axis('off')
#       3 plt.show()
#
# ~/conda/envs/python/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2681         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2682         resample=resample, url=url, **({"data": data} if data is not
# -> 2683         None else {}), **kwargs)
#    2684     sci(__ret)
#    2685     return __ret
#
# ~/conda/envs/python/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
# ...
